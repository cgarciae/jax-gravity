# %%
EqX := D[X[t] == R Sin[Theta[t]] Cos[Phi[t]], t]
EqX
# Out:
# X'[t] == -(R Sin[Phi[t]] Sin[Theta[t]] Phi'[t]) + R Cos[Phi[t]] Cos[Theta[t]] Theta'[t]

# %%
EqY := D[Y[t] == R Sin[Theta[t]] Sin[Phi[t]], t]
EqY
# Out:
# Y'[t] == R Cos[Phi[t]] Sin[Theta[t]] Phi'[t] + R Cos[Theta[t]] Sin[Phi[t]] Theta'[t]
