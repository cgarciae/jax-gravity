# %%
sol := Solve[
    Dphihat == −Rhat Dphi Sin[Theta] − Phihat Phi Cos[Theta] && 
    Dthetahat == −Rhat Dtheta + Phihat Dphi Cos[Theta],
    {Dphi, Dtheta}
]
sol
# Out:
#             Phi Phihat Cot[Theta] + Dphihat Csc[Theta]
# {{Dphi -> -(------------------------------------------),
#                                Rhat
#
# >    Dtheta -> -(
#
#                                                                 2
#          Dthetahat Rhat + Dphihat Phihat Cot[Theta] + Phi Phihat  Cos[Theta] Cot[Theta]
# >        ------------------------------------------------------------------------------)}
#                                                  2
#                                              Rhat
#
# >    }

# %%
ToString[sol[[1]][[1]], InputForm]
# Out:
# Dphi -> -((Phi*Phihat*Cot[Theta] + Dphihat*Csc[Theta])/Rhat)

# %%
ToString[sol[[1]][[2]], InputForm]
# Out:
# Dtheta -> -((Dthetahat*Rhat + Dphihat*Phihat*Cot[Theta] +\
#
# >   Phi*Phihat^2*Cos[Theta]*Cot[Theta])/Rhat^2)
